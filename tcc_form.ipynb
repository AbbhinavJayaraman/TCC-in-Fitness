# %% [markdown]
# # TCC Playground
#
# Using this Colab, you can play with the Temporal Cycle Consistency algorithm on your data. It is a self-supervised method to train image/video encoders (like ResNet etc.) by looking for similarities in sets of images or frames of videos.
#
# ![alt text](https://1.bp.blogspot.com/-zhVafTWua44/XUtMTlA36sI/AAAAAAAAEZU/ZyREcK5HIpoup5XtFErogXz66XDyxKJBwCLcBGAs/s640/image2.gif)
#
# Once this encoder has been trained, it can be used for a number of downstream applications, two of which are included in this Colab. One task is to propagate temporal labels from a handful of videos to the entire dataset (few-shot learning). For example, you can mark a phase/segment (lifting the bottle up) of an action (pouring) in one video, then these labels can be transferred to other videos using the TCC embeddings. Another task is synchronizing similar actions in videos. Following is an example result of aligning videos of people pitching a baseball using TCC.
#
# ![alt text](https://1.bp.blogspot.com/-x5R7gEPTyWE/XUtMYCn3API/AAAAAAAAEZ8/9WyGQMi2cOEtEqi6hwMN9TO-LSrAkG7_ACEwYBhgL/s640/image1.gif).
#
# More details can be found in the [blogpost](https://ai.googleblog.com/2019/08/video-understanding-using-temporal.html) and [paper](https://arxiv.org/abs/1904.07846). If you find this useful, the full [codebase](https://github.com/google-research/google-research/tree/master/tcc) has a lot more functionality.

# %% [markdown]
# ## CS 381V Final Project Alterations
#
# For this project, I've separated out this notebook to focus on the tempo of the exercise.
#
# What do we mean by "tempo"? This simply means the **time (or ratio of time) spent in the concentric, isometric, and eccentric motion** of the exercise.
#
# **Concentric** = Contraction of the muscle.
# **Isometric** = Holding the pose, no motion, typically in a lengthened muscle position.
# **Eccentric** = Relaxing of the muscle, opposite of the concentric motion.
#
# Our focus on this is based on the current consensus in health and kinesiolgy research, in that the eccentric motion when performed in a controlled and slow manner in comparison to the concentric and isometric, is extremely and most conducive to muscle growth stimulus, irrespective of whether the goal is to gain strength or increase muscle size. From there, a good pause on the isometric aspect, specifically when the muscle(s) are in their lengthened position, is the next in terms of strength/contribution to the stimulus. Finally, while the concentric motion has the least amount of contribution to the stimulus comparatively, a controlled but explosive concentric motion is specically conducive/transferable for/to athletic applications.
#
# For the scope of this project, at least for the main bulk of the work, we will be operating under a binary classlification of good/bad tempo. The same will apply for the ROM and Form TCC notebooks.

# %% [markdown]
# # Setup
#
# Ensure you are running on a GPU Colab runtime. Run the following two cells that sets up all code to run the playground.

# %%
# !pip install tensorflow==2.18 opencv-python matplotlib scikit-learn dtw-python tensorboard
# Out:
# Requirement already satisfied: tensorflow==2.18 in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting dtw-python
#   Downloading dtw_python-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (1.71.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.18) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow==2.18) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18) (0.1.2)
# Downloading dtw_python-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (801 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.7/801.7 kB 35.1 MB/s eta 0:00:00
# Installing collected packages: dtw-python
# Successfully installed dtw-python-1.5.3

# %%
#@title Installs and imports
import cv2
import glob
import os
import math

from google.colab import drive

from tqdm import tqdm

import matplotlib
from matplotlib.animation import FuncAnimation
import matplotlib.pyplot as plt

from IPython.display import HTML
from base64 import b64encode

import numpy as np

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, f1_score

import tensorflow as tf

# !pip install dtw
from dtw import dtw

from tensorboard import notebook
# %load_ext tensorboard
# Out:
# Collecting dtw
#   Downloading dtw-1.4.0.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from dtw) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from dtw) (1.15.2)
# Building wheels for collected packages: dtw
#   Building wheel for dtw (setup.py) ... done
#   Created wheel for dtw: filename=dtw-1.4.0-py3-none-any.whl size=5301 sha256=801a1032fb0d12b2cbeb1ca965bc0fc47279b8fa994a95165ae88e6aa1382b7f
#   Stored in directory: /root/.cache/pip/wheels/2c/16/01/ffea89493a0fcd29934418eb0bf10161470acf8d5647bab656
# Successfully built dtw
# Installing collected packages: dtw
# Successfully installed dtw-1.4.0

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#@title TCC Codebase.

# Data Loading Utils
def read_video(video_filename, width=224, height=224):
  cap = cv2.VideoCapture(video_filename)
  frames = []
  if cap.isOpened():
    while True:
      success, frame_bgr = cap.read()
      if not success:
        break
      frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
      frame_rgb = cv2.resize(frame_rgb, (width, height))
      frames.append(frame_rgb)
  frames = np.asarray(frames)
  return frames

def pad_zeros(frames, max_seq_len):
  npad = ((0, max_seq_len-len(frames)), (0, 0), (0, 0), (0, 0))
  frames = np.pad(frames, pad_width=npad, mode='constant', constant_values=0)
  return frames


def load_videos(path_to_raw_videos):
  drive.mount('/content/gdrive')
  video_filenames = sorted(glob.glob(os.path.join(path_to_raw_videos, '*.mp4')))
  print('Found %d videos to align.'%len(video_filenames))
  videos = []
  video_seq_lens = []
  for video_filename in video_filenames:
    frames = read_video(video_filename)
    videos.append(frames)
    video_seq_lens.append(len(frames))
  max_seq_len = max(video_seq_lens)
  videos = np.asarray([pad_zeros(x, max_seq_len) for x in videos])
  return videos, video_seq_lens


def play_video(video, video_seq_len):
  video = video[:video_seq_len]
  path_to_output_video = '/tmp/video.mp4'
  num_frames = len(video)
  fig, ax = plt.subplots(ncols=1, figsize=(5, 5), tight_layout=True)

  im0 = ax.imshow(unnorm(video[0]))
  def update(i):
    """Update plot with next frame."""
    im0.set_data(unnorm(video[i]))
    # Hide grid lines
    ax.grid(False)
    ax.set_title('Frame # %d'%i)
    # Hide axes ticks
    ax.set_xticks([])
    ax.set_yticks([])
    plt.tight_layout()

  anim = FuncAnimation(
      fig,
      update,
      frames=np.arange(num_frames),
      interval=200,
      blit=False)
  anim.save(path_to_output_video, dpi=80)
  plt.close()
  return show_video(path_to_output_video)


def viz_propagated_labels(video,
                          labels,
                          video_seq_len,
                          label_strings=None):
  video = video[:video_seq_len]
  path_to_output_video = '/tmp/labeled_video.mp4'
  if not label_strings:
    label_strings = [str(x) for x in range(np.max(labels))]
  num_frames = len(video)

  fig, ax = plt.subplots(ncols=1, figsize=(5, 5), tight_layout=True)

  im0 = ax.imshow(unnorm(video[0]))
  def update(i):
    """Update plot with next frame."""
    im0.set_data(unnorm(video[i]))
    # Hide grid lines
    ax.grid(False)
    ax.set_title('Label: %s'%label_strings[labels[i]])
    # Hide axes ticks
    ax.set_xticks([])
    ax.set_yticks([])
    plt.tight_layout()

  anim = FuncAnimation(
      fig,
      update,
      frames=np.arange(num_frames),
      interval=100,
      blit=False)
  anim.save(path_to_output_video, dpi=80)
  plt.close()
  return show_video(path_to_output_video)


def create_dataset(videos, seq_lens, batch_size, num_steps,
                   num_context_steps, context_stride):
  ds = tf.data.Dataset.from_tensor_slices((videos, seq_lens))
  ds = ds.repeat()
  ds = ds.shuffle(len(videos))

  def sample_and_preprocess(video, seq_len):
    steps = tf.sort(tf.random.shuffle(tf.range(seq_len))[:num_steps])

    def get_context_steps(step):
      return tf.clip_by_value(
          tf.range(step - (num_context_steps - 1) * context_stride,
                   step + context_stride,
                   context_stride),
                   0, seq_len-1)

    steps_with_context = tf.reshape(
        tf.map_fn(get_context_steps, steps), [-1])
    frames = tf.gather(video, steps_with_context)
    frames = tf.cast(frames, tf.float32)
    frames = (frames/127.5) - 1.0
    frames = tf.image.resize(frames, (168, 168))
    return {'frames': frames,
            'seq_lens': seq_len,
            'steps': steps}

  ds = ds.map(sample_and_preprocess,
              num_parallel_calls=tf.data.experimental.AUTOTUNE)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(1)
  return ds


# TCC Loss
def classification_loss(logits, labels, label_smoothing):
  """Loss function based on classifying the correct indices.
  In the paper, this is called Cycle-back Classification.
  Args:
    logits: Tensor, Pre-softmax scores used for classification loss. These are
      similarity scores after cycling back to the starting sequence.
    labels: Tensor, One hot labels containing the ground truth. The index where
      the cycle started is 1.
    label_smoothing: Float, label smoothing factor which can be used to
      determine how hard the alignment should be.
  Returns:
    loss: Tensor, A scalar classification loss calculated using standard softmax
      cross-entropy loss.
  """
  # Just to be safe, we stop gradients from labels as we are generating labels.
  labels = tf.stop_gradient(labels)
  return tf.reduce_mean(tf.keras.losses.categorical_crossentropy(
      y_true=labels, y_pred=logits, from_logits=True,
      label_smoothing=label_smoothing))


def regression_loss(logits, labels, num_steps, steps, seq_lens, loss_type,
                    normalize_indices, variance_lambda, huber_delta):
  """Loss function based on regressing to the correct indices.
  In the paper, this is called Cycle-back Regression. There are 3 variants
  of this loss:
  i) regression_mse: MSE of the predicted indices and ground truth indices.
  ii) regression_mse_var: MSE of the predicted indices that takes into account
  the variance of the similarities. This is important when the rate at which
  sequences go through different phases changes a lot. The variance scaling
  allows dynamic weighting of the MSE loss based on the similarities.
  iii) regression_huber: Huber loss between the predicted indices and ground
  truth indices.
  Args:
    logits: Tensor, Pre-softmax similarity scores after cycling back to the
      starting sequence.
    labels: Tensor, One hot labels containing the ground truth. The index where
      the cycle started is 1.
    num_steps: Integer, Number of steps in the sequence embeddings.
    steps: Tensor, step indices/frame indices of the embeddings of the shape
      [N, T] where N is the batch size, T is the number of the timesteps.
    seq_lens: Tensor, Lengths of the sequences from which the sampling was done.
      This can provide additional temporal information to the alignment loss.
    loss_type: String, This specifies the kind of regression loss function.
      Currently supported loss functions: regression_mse, regression_mse_var,
      regression_huber.
    normalize_indices: Boolean, If True, normalizes indices by sequence lengths.
      Useful for ensuring numerical instabilities don't arise as sequence
      indices can be large numbers.
    variance_lambda: Float, Weight of the variance of the similarity
      predictions while cycling back. If this is high then the low variance
      similarities are preferred by the loss while making this term low results
      in high variance of the similarities (more uniform/random matching).
    huber_delta: float, Huber delta described in tf.keras.losses.huber_loss.
  Returns:
     loss: Tensor, A scalar loss calculated using a variant of regression.
  """
  # Just to be safe, we stop gradients from labels as we are generating labels.
  labels = tf.stop_gradient(labels)
  steps = tf.stop_gradient(steps)

  if normalize_indices:
    float_seq_lens = tf.cast(seq_lens, tf.float32)
    tile_seq_lens = tf.tile(
        tf.expand_dims(float_seq_lens, axis=1), [1, num_steps])
    steps = tf.cast(steps, tf.float32) / tile_seq_lens
  else:
    steps = tf.cast(steps, tf.float32)

  beta = tf.nn.softmax(logits)
  true_time = tf.reduce_sum(steps * labels, axis=1)
  pred_time = tf.reduce_sum(steps * beta, axis=1)

  if loss_type in ['regression_mse', 'regression_mse_var']:
    if 'var' in loss_type:
      # Variance aware regression.
      pred_time_tiled = tf.tile(tf.expand_dims(pred_time, axis=1),
                                [1, num_steps])

      pred_time_variance = tf.reduce_sum(
          tf.square(steps - pred_time_tiled) * beta, axis=1)

      # Using log of variance as it is numerically stabler.
      pred_time_log_var = tf.math.log(pred_time_variance)
      squared_error = tf.square(true_time - pred_time)
      return tf.reduce_mean(tf.math.exp(-pred_time_log_var) * squared_error
                            + variance_lambda * pred_time_log_var)

    else:
      return tf.reduce_mean(
          tf.keras.losses.mean_squared_error(y_true=true_time,
                                             y_pred=pred_time))
  elif loss_type == 'regression_huber':
    return tf.reduce_mean(tf.keras.losses.huber_loss(
        y_true=true_time, y_pred=pred_time,
        delta=huber_delta))
  else:
    raise ValueError('Unsupported regression loss %s. Supported losses are: '
                     'regression_mse, regresstion_mse_var and regression_huber.'
                     % loss_type)


def pairwise_l2_distance(embs1, embs2):
  """Computes pairwise distances between all rows of embs1 and embs2."""
  norm1 = tf.reduce_sum(tf.square(embs1), 1)
  norm1 = tf.reshape(norm1, [-1, 1])
  norm2 = tf.reduce_sum(tf.square(embs2), 1)
  norm2 = tf.reshape(norm2, [1, -1])

  # Max to ensure matmul doesn't produce anything negative due to floating
  # point approximations.
  dist = tf.maximum(
      norm1 + norm2 - 2.0 * tf.matmul(embs1, embs2, False, True), 0.0)

  return dist


def get_scaled_similarity(embs1, embs2, similarity_type, temperature):
  """Returns similarity between each all rows of embs1 and all rows of embs2.
  The similarity is scaled by the number of channels/embedding size and
  temperature.
  Args:
    embs1: Tensor, Embeddings of the shape [M, D] where M is the number of
      embeddings and D is the embedding size.
    embs2: Tensor, Embeddings of the shape [N, D] where N is the number of
      embeddings and D is the embedding size.
    similarity_type: String, Either one of 'l2' or 'cosine'.
    temperature: Float, Temperature used in scaling logits before softmax.
  Returns:
    similarity: Tensor, [M, N] tensor denoting similarity between embs1 and
      embs2.
  """
  channels = tf.cast(tf.shape(embs1)[1], tf.float32)
  # Go for embs1 to embs2.
  if similarity_type == 'cosine':
    similarity = tf.matmul(embs1, embs2, transpose_b=True)
  elif similarity_type == 'l2':
    similarity = -1.0 * pairwise_l2_distance(embs1, embs2)
  else:
    raise ValueError('similarity_type can either be l2 or cosine.')

  # Scale the distance  by number of channels. This normalization helps with
  # optimization.
  similarity /= channels
  # Scale the distance by a temperature that helps with how soft/hard the
  # alignment should be.
  similarity /= temperature

  return similarity


def align_pair_of_sequences(embs1,
                            embs2,
                            similarity_type,
                            temperature):
  """Align a given pair embedding sequences.
  Args:
    embs1: Tensor, Embeddings of the shape [M, D] where M is the number of
      embeddings and D is the embedding size.
    embs2: Tensor, Embeddings of the shape [N, D] where N is the number of
      embeddings and D is the embedding size.
    similarity_type: String, Either one of 'l2' or 'cosine'.
    temperature: Float, Temperature used in scaling logits before softmax.
  Returns:
     logits: Tensor, Pre-softmax similarity scores after cycling back to the
      starting sequence.
    labels: Tensor, One hot labels containing the ground truth. The index where
      the cycle started is 1.
  """
  max_num_steps = tf.shape(embs1)[0]

  # Find distances between embs1 and embs2.
  sim_12 = get_scaled_similarity(embs1, embs2, similarity_type, temperature)

  # Softmax the distance.
  softmaxed_sim_12 = tf.nn.softmax(sim_12, axis=1)
  # Calculate soft-nearest neighbors.

  nn_embs = tf.matmul(softmaxed_sim_12, embs2)
  # Find distances between nn_embs and embs1.
  sim_21 = get_scaled_similarity(nn_embs, embs1, similarity_type, temperature)
  logits = sim_21
  labels = tf.one_hot(tf.range(max_num_steps), max_num_steps)

  return logits, labels

def _align_single_cycle(cycle, embs, cycle_length, num_steps,
                        similarity_type, temperature):
  """Takes a single cycle and returns logits (simialrity scores) and labels."""
  # Choose random frame.
  n_idx = tf.random.uniform((), minval=0, maxval=num_steps, dtype=tf.int32)
  # Create labels
  onehot_labels = tf.one_hot(n_idx, num_steps)

  # Choose query feats for first frame.
  query_feats = embs[cycle[0], n_idx:n_idx+1]

  num_channels = tf.shape(query_feats)[-1]
  for c in range(1, cycle_length+1):
    candidate_feats = embs[cycle[c]]

    if similarity_type == 'l2':
      # Find L2 distance.
      mean_squared_distance = tf.reduce_sum(
          tf.square(tf.tile(query_feats, [num_steps, 1])- candidate_feats), axis=1)
      # Convert L2 distance to similarity.
      similarity = -mean_squared_distance

    elif similarity_type == 'cosine':
      # Dot product of embeddings.
      similarity = tf.squeeze(tf.matmul(candidate_feats, query_feats,
                                        transpose_b=True))
    else:
      raise ValueError('similarity_type can either be l2 or cosine.')

    # Scale the distance  by number of channels. This normalization helps with
    # optimization.
    similarity = tf.truediv(similarity,
                            tf.cast(num_channels, tf.float32))
    # # Scale the distance by a temperature that helps with how soft/hard the
    # # alignment should be.
    similarity = tf.truediv(similarity, temperature)

    beta = tf.nn.softmax(similarity)
    beta = tf.expand_dims(beta, axis=1)
    beta = tf.tile(beta, [1, num_channels])

    # Find weighted nearest neighbour.
    query_feats = tf.reduce_sum(beta * candidate_feats,
                                axis=0, keepdims=True)

  return similarity, onehot_labels


def _align(cycles, embs, num_steps, num_cycles, cycle_length,
           similarity_type, temperature):
  """Align by finding cycles in embs."""
  logits_list = []
  labels_list = []
  for i in range(num_cycles):
    logits, labels = _align_single_cycle(cycles[i],
                                         embs,
                                         cycle_length,
                                         num_steps,
                                         similarity_type,
                                         temperature)
    logits_list.append(logits)
    labels_list.append(labels)

  logits = tf.stack(logits_list)
  labels = tf.stack(labels_list)

  return logits, labels


def gen_cycles(num_cycles, batch_size, cycle_length=2):
  """Generates cycles for alignment.
  Generates a batch of indices to cycle over. For example setting num_cycles=2,
  batch_size=5, cycle_length=3 might return something like this:
  cycles = [[0, 3, 4, 0], [1, 2, 0, 3]]. This means we have 2 cycles for which
  the loss will be calculated. The first cycle starts at sequence 0 of the
  batch, then we find a matching step in sequence 3 of that batch, then we
  find matching step in sequence 4 and finally come back to sequence 0,
  completing a cycle.
  Args:
    num_cycles: Integer, Number of cycles that will be matched in one pass.
    batch_size: Integer, Number of sequences in one batch.
    cycle_length: Integer, Length of the cycles. If we are matching between
      2 sequences (cycle_length=2), we get cycles that look like [0,1,0].
      This means that we go from sequence 0 to sequence 1 then back to sequence
      0. A cycle length of 3 might look like [0, 1, 2, 0].
  Returns:
    cycles: Tensor, Batch indices denoting cycles that will be used for
      calculating the alignment loss.
  """
  sorted_idxes = tf.tile(tf.expand_dims(tf.range(batch_size), 0),
                         [num_cycles, 1])
  sorted_idxes = tf.reshape(sorted_idxes, [batch_size, num_cycles])
  cycles = tf.reshape(tf.random.shuffle(sorted_idxes),
                      [num_cycles, batch_size])
  cycles = cycles[:, :cycle_length]
  # Append the first index at the end to create cycle.
  cycles = tf.concat([cycles, cycles[:, 0:1]], axis=1)
  return cycles


def compute_stochastic_alignment_loss(embs,
                                      steps,
                                      seq_lens,
                                      num_steps,
                                      batch_size,
                                      loss_type,
                                      similarity_type,
                                      num_cycles,
                                      cycle_length,
                                      temperature,
                                      label_smoothing,
                                      variance_lambda,
                                      huber_delta,
                                      normalize_indices):
  """Compute cycle-consistency loss by stochastically sampling cycles.
  Args:
    embs: Tensor, sequential embeddings of the shape [N, T, D] where N is the
      batch size, T is the number of timesteps in the sequence, D is the size of
      the embeddings.
    steps: Tensor, step indices/frame indices of the embeddings of the shape
      [N, T] where N is the batch size, T is the number of the timesteps.
    seq_lens: Tensor, Lengths of the sequences from which the sampling was done.
      This can provide additional information to the alignment loss.
    num_steps: Integer/Tensor, Number of timesteps in the embeddings.
    batch_size: Integer/Tensor, Batch size.
    loss_type: String, This specifies the kind of loss function to use.
      Currently supported loss functions: 'classification', 'regression_mse',
      'regression_mse_var', 'regression_huber'.
    similarity_type: String, Currently supported similarity metrics: 'l2',
      'cosine'.
    num_cycles: Integer, number of cycles to match while aligning
      stochastically.  Only used in the stochastic version.
    cycle_length: Integer, Lengths of the cycle to use for matching. Only used
      in the stochastic version. By default, this is set to 2.
    temperature: Float, temperature scaling used to scale the similarity
      distributions calculated using the softmax function.
    label_smoothing: Float, Label smoothing argument used in
      tf.keras.losses.categorical_crossentropy function and described in this
      paper https://arxiv.org/pdf/1701.06548.pdf.
    variance_lambda: Float, Weight of the variance of the similarity
      predictions while cycling back. If this is high then the low variance
      similarities are preferred by the loss while making this term low results
      in high variance of the similarities (more uniform/random matching).
    huber_delta: float, Huber delta described in tf.keras.losses.huber_loss.
    normalize_indices: Boolean, If True, normalizes indices by sequence lengths.
      Useful for ensuring numerical instabilities doesn't arise as sequence
      indices can be large numbers.
  Returns:
    loss: Tensor, Scalar loss tensor that imposes the chosen variant of the
      cycle-consistency loss.
  """
  # Generate cycles.
  cycles = gen_cycles(num_cycles, batch_size, cycle_length)

  logits, labels = _align(cycles, embs, num_steps, num_cycles, cycle_length,
                          similarity_type, temperature)

  if loss_type == 'classification':
    loss = classification_loss(logits, labels, label_smoothing)
  elif 'regression' in loss_type:
    steps = tf.gather(steps, cycles[:, 0])
    seq_lens = tf.gather(seq_lens, cycles[:, 0])
    loss = regression_loss(logits, labels, num_steps, steps, seq_lens,
                           loss_type, normalize_indices, variance_lambda,
                           huber_delta)
  else:
    raise ValueError('Unidentified loss type %s. Currently supported loss '
                     'types are: regression_mse, regression_huber, '
                     'classification .'
                     % loss_type)
  return loss


def compute_deterministic_alignment_loss(embs,
                                         steps,
                                         seq_lens,
                                         num_steps,
                                         batch_size,
                                         loss_type,
                                         similarity_type,
                                         temperature,
                                         label_smoothing,
                                         variance_lambda,
                                         huber_delta,
                                         normalize_indices):
  """Compute cycle-consistency loss for all steps in each sequence.
  This aligns each pair of videos in the batch except with itself.
  When aligning it also matters which video is the starting video. So for N
  videos in the batch, we have N * (N-1) alignments happening.
  For example, a batch of size 3 has 6 pairs of sequence alignments.
  Args:
    embs: Tensor, sequential embeddings of the shape [N, T, D] where N is the
      batch size, T is the number of timesteps in the sequence, D is the size
      of the embeddings.
    steps: Tensor, step indices/frame indices of the embeddings of the shape
      [N, T] where N is the batch size, T is the number of the timesteps.
    seq_lens: Tensor, Lengths of the sequences from which the sampling was
    done. This can provide additional information to the alignment loss.
    num_steps: Integer/Tensor, Number of timesteps in the embeddings.
    batch_size: Integer, Size of the batch.
    loss_type: String, This specifies the kind of loss function to use.
      Currently supported loss functions: 'classification', 'regression_mse',
      'regression_mse_var', 'regression_huber'.
    similarity_type: String, Currently supported similarity metrics: 'l2' ,
      'cosine' .
    temperature: Float, temperature scaling used to scale the similarity
      distributions calculated using the softmax function.
    label_smoothing: Float, Label smoothing argument used in
      tf.keras.losses.categorical_crossentropy function and described in this
      paper https://arxiv.org/pdf/1701.06548.pdf.
    variance_lambda: Float, Weight of the variance of the similarity
      predictions while cycling back. If this is high then the low variance
      similarities are preferred by the loss while making this term low
      results in high variance of the similarities (more uniform/random
      matching).
    huber_delta: float, Huber delta described in tf.keras.losses.huber_loss.
    normalize_indices: Boolean, If True, normalizes indices by sequence
      lengths. Useful for ensuring numerical instabilities doesn't arise as
      sequence indices can be large numbers.
  Returns:
    loss: Tensor, Scalar loss tensor that imposes the chosen variant of the
        cycle-consistency loss.
  """
  labels_list = []
  logits_list = []
  steps_list = []
  seq_lens_list = []

  for i in range(batch_size):
    for j in range(batch_size):
      # We do not align the sequence with itself.
      if i != j:
        logits, labels = align_pair_of_sequences(embs[i],
                                                 embs[j],
                                                 similarity_type,
                                                 temperature)
        logits_list.append(logits)
        labels_list.append(labels)
        steps_list.append(tf.tile(steps[i:i+1], [num_steps, 1]))
        seq_lens_list.append(tf.tile(seq_lens[i:i+1], [num_steps]))

  logits = tf.concat(logits_list, axis=0)
  labels = tf.concat(labels_list, axis=0)
  steps = tf.concat(steps_list, axis=0)
  seq_lens = tf.concat(seq_lens_list, axis=0)

  if loss_type == 'classification':
    loss = classification_loss(logits, labels, label_smoothing)
  elif 'regression' in loss_type:
    loss = regression_loss(logits, labels, num_steps, steps, seq_lens,
                           loss_type, normalize_indices, variance_lambda,
                           huber_delta)
  else:
    raise ValueError('Unidentified loss_type %s. Currently supported loss '
                     'types are: regression_mse, regression_huber, '
                     'classification.' % loss_type)

  return loss

# Visualization code
def dist_fn(x, y):
  dist = np.sum((x-y)**2)
  return dist


def get_nn(embs, query_emb):
  dist = np.linalg.norm(embs - query_emb, axis=1)
  assert len(dist) == len(embs)
  return np.argmin(dist), np.min(dist)


def unnorm(query_frame):
  min_v = query_frame.min()
  max_v = query_frame.max()
  query_frame = (query_frame - min_v) / (max_v - min_v)
  return query_frame


def viz_align(query_feats, candidate_feats, use_dtw):
  """Align videos based on dynamic time warping."""
  if use_dtw:
    _, _, _, path = dtw(query_feats, candidate_feats, dist=dist_fn)
    _, uix = np.unique(path[0], return_index=True)
    nns = path[1][uix]
  else:
    nns = []
    for i in range(len(query_feats)):
      nn_frame_id, _ = get_nn(candidate_feats, query_feats[i])
      nns.append(nn_frame_id)
  return nns

def show_video(video_path):
  mp4 = open(video_path,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""<video width=600 controls>
      <source src="%s" type="video/mp4"></video>
  """ % data_url)


def create_video(embs, frames, video_path, use_dtw, query=0):
  """Create aligned videos."""
  # If candiidate is not None implies alignment is being calculated between
  # 2 videos only.

  ncols = int(math.sqrt(len(embs)))
  fig, ax = plt.subplots(
      ncols=ncols,
      nrows=ncols,
      figsize=(5 * ncols, 5 * ncols),
      tight_layout=True)

  nns = []
  for candidate in range(len(embs)):
    nns.append(viz_align(embs[query], embs[candidate], use_dtw))
  ims = []

  def init():
    k = 0
    for k in range(ncols):
      for j in range(ncols):
        ims.append(ax[j][k].imshow(
            unnorm(frames[k * ncols + j][nns[k * ncols + j][0]])))
        ax[j][k].grid(False)
        ax[j][k].set_xticks([])
        ax[j][k].set_yticks([])
    return ims

  ims = init()

  def update(i):
    for k in range(ncols):
      for j in range(ncols):
        ims[k * ncols + j].set_data(
            unnorm(frames[k * ncols + j][nns[k * ncols + j][i]]))
    plt.tight_layout()
    return ims

  anim = FuncAnimation(
      fig,
      update,
      frames=np.arange(len(embs[query])),
      interval=100,
      blit=False)
  anim.save(video_path, dpi=40)
  plt.close()

def create_dynamic_video(embs, frames, video_path, use_dtw, query=0):
  """Create aligned videos."""
  fig, ax = plt.subplots(ncols=2, figsize=(10, 5), tight_layout=True)

  ax[0].set_title('Reference Frame')
  ax[1].set_title('Aligned Frame using TCC')
  nns = []
  for candidate in range(len(embs)):
    nns.append(viz_align(embs[query], embs[candidate], use_dtw))

  switch_video = max(1, len(embs[query])//len(embs))

  im0 = ax[0].imshow(unnorm(frames[0][0]))
  im1 = ax[1].imshow(unnorm(frames[1][nns[1][0]]))

  def update(i):
    """Update plot with next frame."""
    candidate = min(i // switch_video + 1,
                    len(embs)-1)

    im0.set_data(unnorm(frames[query][i]))
    im1.set_data(unnorm(frames[candidate][nns[candidate][i]]))
    # Hide grid lines
    ax[0].grid(False)
    ax[1].grid(False)

    # Hide axes ticks
    ax[0].set_xticks([])
    ax[1].set_xticks([])
    ax[0].set_yticks([])
    ax[1].set_yticks([])
    plt.tight_layout()

  anim = FuncAnimation(
      fig,
      update,
      frames=np.arange(len(embs[query])),
      interval=100,
      blit=False)
  anim.save(video_path, dpi=80)
  plt.close()


def viz_alignment(embs,
                  frames,
                  video_path,
                  grid_mode=True,
                  use_dtw=False,
                  query=0):
  """Visualize alignment."""

  if grid_mode:
    return create_video(
        embs,
        frames,
        video_path,
        use_dtw,
        query)
  else:
    return create_dynamic_video(
        embs,
        frames,
        video_path,
        use_dtw,
        query)

def convert_label_list(label_list, max_seq_len):
  labels = []
  curr_label = 0
  for i in range(max_seq_len):
    if i > label_list[curr_label]:
      curr_label += 1
    labels.append(curr_label)
  return labels


def fit_svm_model(train_embs, train_labels):
  """Fit a SVM classifier."""
  svm_model = SVC(decision_function_shape='ovo', verbose=2)
  svm_model.fit(train_embs, train_labels)
  train_acc = svm_model.score(train_embs, train_labels)
  print('Label propagation model accuracy:', train_acc)
  print('If this is too low, propagation will not work properly.')
  return svm_model

# Propagate labels
def propagate_labels(embs, labels):
  train_embs = []
  train_labels = []
  for video_id in labels:
    max_frame_id = max(labels[video_id])
    train_embs.extend(embs[video_id][:max_frame_id])
    train_labels.extend(convert_label_list(labels[video_id],
                                           max_frame_id))
  model = fit_svm_model(train_embs, train_labels)

  propagated_labels = []
  for video_id in range(len(embs)):
    pred_labels = model.predict(embs[video_id])
    propagated_labels.append(pred_labels)
  return propagated_labels


# Embed videos using model
def get_embs(model, videos, video_seq_lens, frames_per_batch,
             num_context_steps, context_stride):
  embs_list = []
  for video, seq_len in zip(videos, video_seq_lens):
    embs = []
    num_batches = int(np.ceil(float(seq_len)/frames_per_batch))
    for i in range(num_batches):
      steps = np.arange(i*frames_per_batch, (i+1)*frames_per_batch)
      steps = np.clip(steps, 0, seq_len-1)
      def get_context_steps(step):
        return tf.clip_by_value(
          tf.range(step - (num_context_steps - 1) * context_stride,
                   step + context_stride,
                   context_stride),
                   0, seq_len-1)
      steps_with_context = tf.reshape(
        tf.map_fn(get_context_steps, steps), [-1])
      frames = tf.gather(video, steps_with_context)
      frames = tf.cast(frames, tf.float32)
      frames = (frames/127.5)-1.0
      frames = tf.image.resize(frames, (168, 168))
      frames = tf.expand_dims(frames, 0)
      embs.extend(model(frames, training=False).numpy()[0])
    embs = embs[:seq_len]
    assert len(embs) == seq_len
    embs = np.asarray(embs)
    embs_list.append(embs)
  return embs_list


# Embedding Model
class Embedder(tf.keras.Model):
  def __init__(self, embedding_size, normalize_embeddings,
               num_context_steps):
    super().__init__()

    base_model = tf.keras.applications.resnet_v2.ResNet50V2(include_top=False,
                                        weights='imagenet',
                                        pooling='max')
    layer = 'conv4_block3_out'
    self.num_context_steps = num_context_steps
    self.base_model = tf.keras.Model(
        inputs=base_model.input,
        outputs=base_model.get_layer(layer).output)
    self.conv_layers = [tf.keras.layers.Conv3D(256, 3, padding='same')
                        for _ in range(2)]
    self.bn_layers = [tf.keras.layers.BatchNormalization()
                        for _ in range(2)]

    self.fc_layers = [tf.keras.layers.Dense(256,
                                            activation=tf.nn.relu) for _ in range(2)]

    self.embedding_layer = tf.keras.layers.Dense(embedding_size)
    self.normalize_embeddings = normalize_embeddings
    self.dropout = tf.keras.layers.Dropout(0.1)

  def call(self, frames, training):
    batch_size, _, h,  w, c = frames.shape
    frames = tf.reshape(frames,[-1, h, w, c])

    x = self.base_model(frames , training=training)
    _, h,  w, c = x.shape
    x = tf.reshape(x, [-1, self.num_context_steps, h, w, c])

    x = self.dropout(x)

    for conv_layer, bn_layer in zip(self.conv_layers,
                                    self.bn_layers):
      x = conv_layer(x)
      x = bn_layer(x)
      x = tf.nn.relu(x)

    x = tf.reduce_max(x, [1, 2, 3])

    _, c = x.shape
    x = tf.reshape(x, [batch_size, -1, c])

    for fc_layer in self.fc_layers:
      x = self.dropout(x)
      x = fc_layer(x)

    x = self.embedding_layer(x)

    if self.normalize_embeddings:
      x = tf.nn.l2_normalize(x, axis=-1)

    return x

# %% [markdown]
# # Training an Encoder with TCC

# %% [markdown]
# ## Some data pre-processing
# Since we'll be using videos taken from the QEVD dataset, and ones that we have are separated into 6 datasets. Here we will only use two; the good and the bad video folders for the tempo section.
#
# We will add padding to some videos to make them all the same length, downscale to a common resolution, and create a ground truth dictionary as to which videos are considered good tempo and bad tempo.
#
# I did this separation for the sake of being able to run two notebooks at once, since I purchased Colab Pro for this project. Already spent the $10, might as well use it to its fullest extent.

# %%
# !unzip "/content/good_form_250.zip" -d "/content/"
# Out:
# Archive:  /content/good_form_250.zip
#    creating: /content/good_form_250/
#   inflating: /content/good_form_250/00029839.mp4
#   inflating: /content/good_form_250/00058476.mp4
#   inflating: /content/good_form_250/00020478.mp4
#   inflating: /content/good_form_250/00057616.mp4
#   inflating: /content/good_form_250/00297255.mp4
#   inflating: /content/good_form_250/00015808.mp4
#   inflating: /content/good_form_250/00292785.mp4
#   inflating: /content/good_form_250/00049530.mp4
#   inflating: /content/good_form_250/00255307.mp4
#   inflating: /content/good_form_250/00031137.mp4
#   inflating: /content/good_form_250/00053082.mp4
#   inflating: /content/good_form_250/00057676.mp4
#   inflating: /content/good_form_250/00017483.mp4
#   inflating: /content/good_form_250/00033600.mp4
#   inflating: /content/good_form_250/00065575.mp4
#   inflating: /content/good_form_250/00044671.mp4
#   inflating: /content/good_form_250/00232471.mp4
#   inflating: /content/good_form_250/00242412.mp4
#   inflating: /content/good_form_250/00025837.mp4
#   inflating: /content/good_form_250/00008849.mp4
#   inflating: /content/good_form_250/00257328.mp4
#   inflating: /content/good_form_250/00073900.mp4
#   inflating: /content/good_form_250/00055847.mp4
#   inflating: /content/good_form_250/00265386.mp4
#   inflating: /content/good_form_250/00242429.mp4
#   inflating: /content/good_form_250/00249508.mp4
#   inflating: /content/good_form_250/00253163.mp4
#   inflating: /content/good_form_250/00258808.mp4
#   inflating: /content/good_form_250/00057406.mp4
#   inflating: /content/good_form_250/00295046.mp4
#   inflating: /content/good_form_250/00293483.mp4
#   inflating: /content/good_form_250/00252713.mp4
#   inflating: /content/good_form_250/00270383.mp4
#   inflating: /content/good_form_250/00233222.mp4
#   inflating: /content/good_form_250/00290095.mp4
#   inflating: /content/good_form_250/00062651.mp4
#   inflating: /content/good_form_250/00298058.mp4
#   inflating: /content/good_form_250/00290856.mp4
#   inflating: /content/good_form_250/00029598.mp4
#   inflating: /content/good_form_250/00260493.mp4
#   inflating: /content/good_form_250/00073326.mp4
#   inflating: /content/good_form_250/00250447.mp4
#   inflating: /content/good_form_250/00256777.mp4
#   inflating: /content/good_form_250/00008893.mp4
#   inflating: /content/good_form_250/00255911.mp4
#   inflating: /content/good_form_250/00255785.mp4
#   inflating: /content/good_form_250/00235446.mp4
#   inflating: /content/good_form_250/00230728.mp4
#   inflating: /content/good_form_250/00030440.mp4
#   inflating: /content/good_form_250/00250139.mp4
#   inflating: /content/good_form_250/00272187.mp4
#   inflating: /content/good_form_250/00071785.mp4
#   inflating: /content/good_form_250/00051082.mp4
#   inflating: /content/good_form_250/00261328.mp4
#   inflating: /content/good_form_250/00268539.mp4
#   inflating: /content/good_form_250/00261807.mp4
#   inflating: /content/good_form_250/00047321.mp4
#   inflating: /content/good_form_250/00247467.mp4
#   inflating: /content/good_form_250/00235990.mp4
#   inflating: /content/good_form_250/00035643.mp4
#   inflating: /content/good_form_250/00068173.mp4
#   inflating: /content/good_form_250/00228678.mp4
#   inflating: /content/good_form_250/00061016.mp4
#   inflating: /content/good_form_250/00027455.mp4
#   inflating: /content/good_form_250/00034504.mp4
#   inflating: /content/good_form_250/00059810.mp4
#   inflating: /content/good_form_250/00297061.mp4
#   inflating: /content/good_form_250/00263987.mp4
#   inflating: /content/good_form_250/00069135.mp4
#   inflating: /content/good_form_250/00056098.mp4
#   inflating: /content/good_form_250/00229465.mp4
#   inflating: /content/good_form_250/00073455.mp4
#   inflating: /content/good_form_250/00018122.mp4
#   inflating: /content/good_form_250/00234985.mp4
#   inflating: /content/good_form_250/00285187.mp4
#   inflating: /content/good_form_250/00042936.mp4
#   inflating: /content/good_form_250/00235736.mp4
#   inflating: /content/good_form_250/00048903.mp4
#   inflating: /content/good_form_250/00064125.mp4
#   inflating: /content/good_form_250/00255503.mp4
#   inflating: /content/good_form_250/00231238.mp4
#   inflating: /content/good_form_250/00237745.mp4
#   inflating: /content/good_form_250/00241851.mp4
#   inflating: /content/good_form_250/00293404.mp4
#   inflating: /content/good_form_250/00257755.mp4
#   inflating: /content/good_form_250/00259903.mp4
#   inflating: /content/good_form_250/00070581.mp4
#   inflating: /content/good_form_250/00055151.mp4
#   inflating: /content/good_form_250/00256878.mp4
#   inflating: /content/good_form_250/00055250.mp4
#   inflating: /content/good_form_250/00041650.mp4
#   inflating: /content/good_form_250/00294086.mp4
#   inflating: /content/good_form_250/00246123.mp4
#   inflating: /content/good_form_250/00238125.mp4
#   inflating: /content/good_form_250/00031492.mp4
#   inflating: /content/good_form_250/00265910.mp4
#   inflating: /content/good_form_250/00050185.mp4
#   inflating: /content/good_form_250/00258556.mp4
#   inflating: /content/good_form_250/00048681.mp4
#   inflating: /content/good_form_250/00253926.mp4
#   inflating: /content/good_form_250/00281620.mp4
#   inflating: /content/good_form_250/00269617.mp4
#   inflating: /content/good_form_250/00233125.mp4
#   inflating: /content/good_form_250/00015461.mp4
#   inflating: /content/good_form_250/00246686.mp4
#   inflating: /content/good_form_250/00038915.mp4
#   inflating: /content/good_form_250/00063252.mp4
#   inflating: /content/good_form_250/00252502.mp4
#   inflating: /content/good_form_250/00286898.mp4
#   inflating: /content/good_form_250/00035037.mp4
#   inflating: /content/good_form_250/00268215.mp4
#   inflating: /content/good_form_250/00075299.mp4
#   inflating: /content/good_form_250/00268605.mp4
#   inflating: /content/good_form_250/00001629.mp4
#   inflating: /content/good_form_250/00006595.mp4
#   inflating: /content/good_form_250/00239327.mp4
#   inflating: /content/good_form_250/00037415.mp4
#   inflating: /content/good_form_250/00027515.mp4
#   inflating: /content/good_form_250/00245548.mp4
#   inflating: /content/good_form_250/00259084.mp4
#   inflating: /content/good_form_250/00270349.mp4
#   inflating: /content/good_form_250/00295189.mp4
#   inflating: /content/good_form_250/00065598.mp4
#   inflating: /content/good_form_250/00269915.mp4
#   inflating: /content/good_form_250/00015464.mp4
#   inflating: /content/good_form_250/00247372.mp4
#   inflating: /content/good_form_250/00033396.mp4
#   inflating: /content/good_form_250/00263892.mp4
#   inflating: /content/good_form_250/00232788.mp4
#   inflating: /content/good_form_250/00067965.mp4
#   inflating: /content/good_form_250/00010082.mp4
#   inflating: /content/good_form_250/00257654.mp4
#   inflating: /content/good_form_250/00062557.mp4
#   inflating: /content/good_form_250/00045059.mp4
#   inflating: /content/good_form_250/00259563.mp4
#   inflating: /content/good_form_250/00006250.mp4
#   inflating: /content/good_form_250/00034113.mp4
#   inflating: /content/good_form_250/00047791.mp4
#   inflating: /content/good_form_250/00260772.mp4
#   inflating: /content/good_form_250/00068631.mp4
#   inflating: /content/good_form_250/00016820.mp4
#   inflating: /content/good_form_250/00014819.mp4
#   inflating: /content/good_form_250/00024720.mp4
#   inflating: /content/good_form_250/00233557.mp4
#   inflating: /content/good_form_250/00257698.mp4
#   inflating: /content/good_form_250/00240454.mp4
#   inflating: /content/good_form_250/00232198.mp4
#   inflating: /content/good_form_250/00032393.mp4
#   inflating: /content/good_form_250/00244600.mp4
#   inflating: /content/good_form_250/00074730.mp4
#   inflating: /content/good_form_250/00252079.mp4
#   inflating: /content/good_form_250/00257003.mp4
#   inflating: /content/good_form_250/00072045.mp4
#   inflating: /content/good_form_250/00231070.mp4
#   inflating: /content/good_form_250/00072855.mp4
#   inflating: /content/good_form_250/00256887.mp4
#   inflating: /content/good_form_250/00296639.mp4
#   inflating: /content/good_form_250/00240548.mp4
#   inflating: /content/good_form_250/00266979.mp4
#   inflating: /content/good_form_250/00045876.mp4
#   inflating: /content/good_form_250/00236420.mp4
#   inflating: /content/good_form_250/00026141.mp4
#   inflating: /content/good_form_250/00037185.mp4
#   inflating: /content/good_form_250/00055666.mp4
#   inflating: /content/good_form_250/00295191.mp4
#   inflating: /content/good_form_250/00266224.mp4
#   inflating: /content/good_form_250/00234720.mp4
#   inflating: /content/good_form_250/00020208.mp4
#   inflating: /content/good_form_250/00053138.mp4
#   inflating: /content/good_form_250/00243988.mp4
#   inflating: /content/good_form_250/00256161.mp4
#   inflating: /content/good_form_250/00294368.mp4
#   inflating: /content/good_form_250/00023089.mp4
#   inflating: /content/good_form_250/00241494.mp4
#   inflating: /content/good_form_250/00284692.mp4
#   inflating: /content/good_form_250/00264987.mp4
#   inflating: /content/good_form_250/00041532.mp4
#   inflating: /content/good_form_250/00066658.mp4
#   inflating: /content/good_form_250/00038721.mp4
#   inflating: /content/good_form_250/00071133.mp4
#   inflating: /content/good_form_250/00045303.mp4
#   inflating: /content/good_form_250/00267812.mp4
#   inflating: /content/good_form_250/00281779.mp4
#   inflating: /content/good_form_250/00267238.mp4
#   inflating: /content/good_form_250/00062047.mp4
#   inflating: /content/good_form_250/00045516.mp4
#   inflating: /content/good_form_250/00266299.mp4
#   inflating: /content/good_form_250/00290060.mp4
#   inflating: /content/good_form_250/00254828.mp4
#   inflating: /content/good_form_250/00273352.mp4
#   inflating: /content/good_form_250/00023461.mp4
#   inflating: /content/good_form_250/00296201.mp4
#   inflating: /content/good_form_250/00233568.mp4
#   inflating: /content/good_form_250/00279289.mp4
#   inflating: /content/good_form_250/00254159.mp4
#   inflating: /content/good_form_250/00245599.mp4
#   inflating: /content/good_form_250/00234852.mp4
#   inflating: /content/good_form_250/00030887.mp4
#   inflating: /content/good_form_250/00023207.mp4
#   inflating: /content/good_form_250/00065527.mp4
#   inflating: /content/good_form_250/00275269.mp4
#   inflating: /content/good_form_250/00262259.mp4
#   inflating: /content/good_form_250/00236440.mp4
#   inflating: /content/good_form_250/00031002.mp4
#   inflating: /content/good_form_250/00067044.mp4
#   inflating: /content/good_form_250/00257611.mp4
#   inflating: /content/good_form_250/00043320.mp4
#   inflating: /content/good_form_250/00271540.mp4
#   inflating: /content/good_form_250/00267837.mp4
#   inflating: /content/good_form_250/00022026.mp4
#   inflating: /content/good_form_250/00065272.mp4
#   inflating: /content/good_form_250/00248031.mp4
#   inflating: /content/good_form_250/00284717.mp4
#   inflating: /content/good_form_250/00244102.mp4
#   inflating: /content/good_form_250/00049976.mp4
#   inflating: /content/good_form_250/00025171.mp4
#   inflating: /content/good_form_250/00235688.mp4
#   inflating: /content/good_form_250/00263687.mp4
#   inflating: /content/good_form_250/00247786.mp4
#   inflating: /content/good_form_250/00244226.mp4
#   inflating: /content/good_form_250/00297405.mp4
#   inflating: /content/good_form_250/00247272.mp4
#   inflating: /content/good_form_250/00236743.mp4
#   inflating: /content/good_form_250/00283308.mp4
#   inflating: /content/good_form_250/00262707.mp4
#   inflating: /content/good_form_250/00244955.mp4
#   inflating: /content/good_form_250/00032183.mp4
#   inflating: /content/good_form_250/00235878.mp4
#   inflating: /content/good_form_250/00241618.mp4
#   inflating: /content/good_form_250/00039696.mp4
#   inflating: /content/good_form_250/00075146.mp4
#   inflating: /content/good_form_250/00066006.mp4
#   inflating: /content/good_form_250/00293054.mp4
#   inflating: /content/good_form_250/00263697.mp4
#   inflating: /content/good_form_250/00297303.mp4
#   inflating: /content/good_form_250/00041545.mp4
#   inflating: /content/good_form_250/00053265.mp4
#   inflating: /content/good_form_250/00278044.mp4
#   inflating: /content/good_form_250/00263249.mp4
#   inflating: /content/good_form_250/00070178.mp4
#   inflating: /content/good_form_250/00032130.mp4
#   inflating: /content/good_form_250/00028370.mp4
#   inflating: /content/good_form_250/00236414.mp4
#   inflating: /content/good_form_250/00234920.mp4
#   inflating: /content/good_form_250/00254748.mp4
#   inflating: /content/good_form_250/00049674.mp4
#   inflating: /content/good_form_250/00011498.mp4
#   inflating: /content/good_form_250/00048122.mp4
#   inflating: /content/good_form_250/00066435.mp4
#   inflating: /content/good_form_250/00287922.mp4

# %%
# !unzip "/content/bad_form_250.zip" -d "/content/"
# Out:
# Archive:  /content/bad_form_250.zip
#    creating: /content/bad_form_250/
#   inflating: /content/bad_form_250/00018193.mp4
#   inflating: /content/bad_form_250/00075675.mp4
#   inflating: /content/bad_form_250/00025893.mp4
#   inflating: /content/bad_form_250/00037947.mp4
#   inflating: /content/bad_form_250/00025907.mp4
#   inflating: /content/bad_form_250/00003707.mp4
#   inflating: /content/bad_form_250/00275736.mp4
#   inflating: /content/bad_form_250/00050458.mp4
#   inflating: /content/bad_form_250/00073594.mp4
#   inflating: /content/bad_form_250/00035812.mp4
#   inflating: /content/bad_form_250/00042206.mp4
#   inflating: /content/bad_form_250/00067417.mp4
#   inflating: /content/bad_form_250/00071054.mp4
#   inflating: /content/bad_form_250/00261500.mp4
#   inflating: /content/bad_form_250/00248933.mp4
#   inflating: /content/bad_form_250/00074009.mp4
#   inflating: /content/bad_form_250/00235137.mp4
#   inflating: /content/bad_form_250/00031558.mp4
#   inflating: /content/bad_form_250/00014155.mp4
#   inflating: /content/bad_form_250/00012678.mp4
#   inflating: /content/bad_form_250/00269402.mp4
#   inflating: /content/bad_form_250/00037852.mp4
#   inflating: /content/bad_form_250/00011125.mp4
#   inflating: /content/bad_form_250/00043168.mp4
#   inflating: /content/bad_form_250/00048263.mp4
#   inflating: /content/bad_form_250/00002436.mp4
#   inflating: /content/bad_form_250/00016943.mp4
#   inflating: /content/bad_form_250/00023760.mp4
#   inflating: /content/bad_form_250/00069319.mp4
#   inflating: /content/bad_form_250/00290482.mp4
#   inflating: /content/bad_form_250/00285853.mp4
#   inflating: /content/bad_form_250/00073648.mp4
#   inflating: /content/bad_form_250/00008536.mp4
#   inflating: /content/bad_form_250/00044296.mp4
#   inflating: /content/bad_form_250/00042887.mp4
#   inflating: /content/bad_form_250/00010209.mp4
#   inflating: /content/bad_form_250/00051696.mp4
#   inflating: /content/bad_form_250/00261056.mp4
#   inflating: /content/bad_form_250/00069105.mp4
#   inflating: /content/bad_form_250/00273133.mp4
#   inflating: /content/bad_form_250/00052683.mp4
#   inflating: /content/bad_form_250/00053009.mp4
#   inflating: /content/bad_form_250/00012835.mp4
#   inflating: /content/bad_form_250/00053925.mp4
#   inflating: /content/bad_form_250/00019645.mp4
#   inflating: /content/bad_form_250/00266536.mp4
#   inflating: /content/bad_form_250/00015929.mp4
#   inflating: /content/bad_form_250/00041404.mp4
#   inflating: /content/bad_form_250/00030487.mp4
#   inflating: /content/bad_form_250/00290725.mp4
#   inflating: /content/bad_form_250/00071732.mp4
#   inflating: /content/bad_form_250/00032222.mp4
#   inflating: /content/bad_form_250/00282906.mp4
#   inflating: /content/bad_form_250/00291199.mp4
#   inflating: /content/bad_form_250/00075940.mp4
#   inflating: /content/bad_form_250/00002553.mp4
#   inflating: /content/bad_form_250/00033067.mp4
#   inflating: /content/bad_form_250/00258099.mp4
#   inflating: /content/bad_form_250/00297184.mp4
#   inflating: /content/bad_form_250/00053835.mp4
#   inflating: /content/bad_form_250/00285286.mp4
#   inflating: /content/bad_form_250/00029323.mp4
#   inflating: /content/bad_form_250/00237715.mp4
#   inflating: /content/bad_form_250/00236340.mp4
#   inflating: /content/bad_form_250/00240963.mp4
#   inflating: /content/bad_form_250/00039996.mp4
#   inflating: /content/bad_form_250/00037544.mp4
#   inflating: /content/bad_form_250/00052784.mp4
#   inflating: /content/bad_form_250/00011260.mp4
#   inflating: /content/bad_form_250/00038639.mp4
#   inflating: /content/bad_form_250/00296592.mp4
#   inflating: /content/bad_form_250/00007723.mp4
#   inflating: /content/bad_form_250/00018173.mp4
#   inflating: /content/bad_form_250/00068439.mp4
#   inflating: /content/bad_form_250/00240207.mp4
#   inflating: /content/bad_form_250/00249410.mp4
#   inflating: /content/bad_form_250/00069583.mp4
#   inflating: /content/bad_form_250/00024907.mp4
#   inflating: /content/bad_form_250/00258086.mp4
#   inflating: /content/bad_form_250/00268668.mp4
#   inflating: /content/bad_form_250/00004827.mp4
#   inflating: /content/bad_form_250/00002820.mp4
#   inflating: /content/bad_form_250/00047239.mp4
#   inflating: /content/bad_form_250/00062397.mp4
#   inflating: /content/bad_form_250/00285921.mp4
#   inflating: /content/bad_form_250/00236226.mp4
#   inflating: /content/bad_form_250/00272874.mp4
#   inflating: /content/bad_form_250/00229799.mp4
#   inflating: /content/bad_form_250/00018766.mp4
#   inflating: /content/bad_form_250/00291688.mp4
#   inflating: /content/bad_form_250/00251717.mp4
#   inflating: /content/bad_form_250/00059141.mp4
#   inflating: /content/bad_form_250/00260575.mp4
#   inflating: /content/bad_form_250/00026308.mp4
#   inflating: /content/bad_form_250/00250794.mp4
#   inflating: /content/bad_form_250/00025920.mp4
#   inflating: /content/bad_form_250/00254444.mp4
#   inflating: /content/bad_form_250/00284788.mp4
#   inflating: /content/bad_form_250/00025012.mp4
#   inflating: /content/bad_form_250/00051952.mp4
#   inflating: /content/bad_form_250/00242795.mp4
#   inflating: /content/bad_form_250/00296516.mp4
#   inflating: /content/bad_form_250/00271327.mp4
#   inflating: /content/bad_form_250/00271224.mp4
#   inflating: /content/bad_form_250/00071090.mp4
#   inflating: /content/bad_form_250/00265878.mp4
#   inflating: /content/bad_form_250/00050517.mp4
#   inflating: /content/bad_form_250/00239570.mp4
#   inflating: /content/bad_form_250/00287692.mp4
#   inflating: /content/bad_form_250/00012406.mp4
#   inflating: /content/bad_form_250/00281840.mp4
#   inflating: /content/bad_form_250/00004947.mp4
#   inflating: /content/bad_form_250/00062793.mp4
#   inflating: /content/bad_form_250/00269555.mp4
#   inflating: /content/bad_form_250/00001087.mp4
#   inflating: /content/bad_form_250/00073809.mp4
#   inflating: /content/bad_form_250/00293560.mp4
#   inflating: /content/bad_form_250/00288827.mp4
#   inflating: /content/bad_form_250/00240744.mp4
#   inflating: /content/bad_form_250/00235831.mp4
#   inflating: /content/bad_form_250/00070137.mp4
#   inflating: /content/bad_form_250/00020075.mp4
#   inflating: /content/bad_form_250/00281635.mp4
#   inflating: /content/bad_form_250/00274096.mp4
#   inflating: /content/bad_form_250/00294016.mp4
#   inflating: /content/bad_form_250/00044398.mp4
#   inflating: /content/bad_form_250/00022513.mp4
#   inflating: /content/bad_form_250/00276080.mp4
#   inflating: /content/bad_form_250/00294651.mp4
#   inflating: /content/bad_form_250/00061747.mp4
#   inflating: /content/bad_form_250/00242685.mp4
#   inflating: /content/bad_form_250/00054456.mp4
#   inflating: /content/bad_form_250/00017042.mp4
#   inflating: /content/bad_form_250/00268233.mp4
#   inflating: /content/bad_form_250/00053230.mp4
#   inflating: /content/bad_form_250/00231937.mp4
#   inflating: /content/bad_form_250/00279540.mp4
#   inflating: /content/bad_form_250/00021131.mp4
#   inflating: /content/bad_form_250/00241232.mp4
#   inflating: /content/bad_form_250/00017164.mp4
#   inflating: /content/bad_form_250/00236478.mp4
#   inflating: /content/bad_form_250/00283587.mp4
#   inflating: /content/bad_form_250/00023206.mp4
#   inflating: /content/bad_form_250/00066714.mp4
#   inflating: /content/bad_form_250/00040979.mp4
#   inflating: /content/bad_form_250/00235215.mp4
#   inflating: /content/bad_form_250/00261840.mp4
#   inflating: /content/bad_form_250/00015502.mp4
#   inflating: /content/bad_form_250/00010503.mp4
#   inflating: /content/bad_form_250/00283025.mp4
#   inflating: /content/bad_form_250/00045264.mp4
#   inflating: /content/bad_form_250/00268834.mp4
#   inflating: /content/bad_form_250/00281530.mp4
#   inflating: /content/bad_form_250/00036183.mp4
#   inflating: /content/bad_form_250/00279640.mp4
#   inflating: /content/bad_form_250/00034332.mp4
#   inflating: /content/bad_form_250/00258726.mp4
#   inflating: /content/bad_form_250/00013900.mp4
#   inflating: /content/bad_form_250/00023629.mp4
#   inflating: /content/bad_form_250/00048045.mp4
#   inflating: /content/bad_form_250/00068028.mp4
#   inflating: /content/bad_form_250/00026882.mp4
#   inflating: /content/bad_form_250/00037535.mp4
#   inflating: /content/bad_form_250/00276282.mp4
#   inflating: /content/bad_form_250/00043787.mp4
#   inflating: /content/bad_form_250/00075857.mp4
#   inflating: /content/bad_form_250/00011926.mp4
#   inflating: /content/bad_form_250/00048047.mp4
#   inflating: /content/bad_form_250/00025593.mp4
#   inflating: /content/bad_form_250/00014696.mp4
#   inflating: /content/bad_form_250/00285592.mp4
#   inflating: /content/bad_form_250/00266745.mp4
#   inflating: /content/bad_form_250/00278756.mp4
#   inflating: /content/bad_form_250/00017429.mp4
#   inflating: /content/bad_form_250/00283000.mp4
#   inflating: /content/bad_form_250/00001655.mp4
#   inflating: /content/bad_form_250/00245197.mp4
#   inflating: /content/bad_form_250/00029940.mp4
#   inflating: /content/bad_form_250/00047117.mp4
#   inflating: /content/bad_form_250/00071432.mp4
#   inflating: /content/bad_form_250/00246599.mp4
#   inflating: /content/bad_form_250/00237147.mp4
#   inflating: /content/bad_form_250/00284320.mp4
#   inflating: /content/bad_form_250/00005974.mp4
#   inflating: /content/bad_form_250/00019343.mp4
#   inflating: /content/bad_form_250/00036064.mp4
#   inflating: /content/bad_form_250/00250849.mp4
#   inflating: /content/bad_form_250/00278099.mp4
#   inflating: /content/bad_form_250/00060097.mp4
#   inflating: /content/bad_form_250/00017414.mp4
#   inflating: /content/bad_form_250/00283226.mp4
#   inflating: /content/bad_form_250/00242829.mp4
#   inflating: /content/bad_form_250/00071409.mp4
#   inflating: /content/bad_form_250/00037963.mp4
#   inflating: /content/bad_form_250/00242286.mp4
#   inflating: /content/bad_form_250/00021369.mp4
#   inflating: /content/bad_form_250/00064443.mp4
#   inflating: /content/bad_form_250/00012180.mp4
#   inflating: /content/bad_form_250/00272310.mp4
#   inflating: /content/bad_form_250/00072590.mp4
#   inflating: /content/bad_form_250/00018989.mp4
#   inflating: /content/bad_form_250/00001051.mp4
#   inflating: /content/bad_form_250/00020200.mp4
#   inflating: /content/bad_form_250/00271181.mp4
#   inflating: /content/bad_form_250/00016923.mp4
#   inflating: /content/bad_form_250/00235407.mp4
#   inflating: /content/bad_form_250/00231356.mp4
#   inflating: /content/bad_form_250/00056422.mp4
#   inflating: /content/bad_form_250/00285771.mp4
#   inflating: /content/bad_form_250/00264754.mp4
#   inflating: /content/bad_form_250/00260961.mp4
#   inflating: /content/bad_form_250/00298054.mp4
#   inflating: /content/bad_form_250/00271676.mp4
#   inflating: /content/bad_form_250/00026364.mp4
#   inflating: /content/bad_form_250/00228111.mp4
#   inflating: /content/bad_form_250/00258716.mp4
#   inflating: /content/bad_form_250/00252402.mp4
#   inflating: /content/bad_form_250/00233859.mp4
#   inflating: /content/bad_form_250/00022393.mp4
#   inflating: /content/bad_form_250/00244851.mp4
#   inflating: /content/bad_form_250/00268401.mp4
#   inflating: /content/bad_form_250/00270333.mp4
#   inflating: /content/bad_form_250/00023278.mp4
#   inflating: /content/bad_form_250/00268346.mp4
#   inflating: /content/bad_form_250/00245832.mp4
#   inflating: /content/bad_form_250/00263762.mp4
#   inflating: /content/bad_form_250/00263916.mp4
#   inflating: /content/bad_form_250/00246007.mp4
#   inflating: /content/bad_form_250/00272177.mp4
#   inflating: /content/bad_form_250/00273762.mp4
#   inflating: /content/bad_form_250/00005486.mp4
#   inflating: /content/bad_form_250/00240669.mp4
#   inflating: /content/bad_form_250/00289458.mp4
#   inflating: /content/bad_form_250/00228817.mp4
#   inflating: /content/bad_form_250/00274320.mp4
#   inflating: /content/bad_form_250/00257040.mp4
#   inflating: /content/bad_form_250/00243778.mp4
#   inflating: /content/bad_form_250/00030697.mp4
#   inflating: /content/bad_form_250/00239371.mp4
#   inflating: /content/bad_form_250/00259695.mp4
#   inflating: /content/bad_form_250/00236461.mp4
#   inflating: /content/bad_form_250/00229803.mp4
#   inflating: /content/bad_form_250/00264059.mp4
#   inflating: /content/bad_form_250/00254654.mp4
#   inflating: /content/bad_form_250/00232934.mp4
#   inflating: /content/bad_form_250/00248276.mp4
#   inflating: /content/bad_form_250/00255147.mp4
#   inflating: /content/bad_form_250/00270565.mp4
#   inflating: /content/bad_form_250/00281495.mp4
#   inflating: /content/bad_form_250/00248119.mp4

# %%
NUM_VIDS_GOOD_BAD = 100 # just wanna test with 100, hopefully trains faster.

# %%
BASE_DIR = '/content/'

video_paths = []
file_labels = {}  # key: filename (no path), value: 'good' or 'bad', will use for eval on testing set.

for subset in ['good_form_250', 'bad_form_250']:
    label = 'good' if subset.startswith('good_') else 'bad'
    folder = os.path.join(BASE_DIR, subset)

    # Get all .mp4 files, sort them
    paths = sorted(glob.glob(os.path.join(folder, '*.mp4')))[:NUM_VIDS_GOOD_BAD]
    for path in paths:
        fname = os.path.basename(path)
        video_paths.append(path)
        file_labels[fname] = label

print(f"Total videos: {len(video_paths)}")
print("Good vs. Bad counts:",
      sum(1 for f in file_labels if file_labels[f] == 'good'),
      sum(1 for f in file_labels if file_labels[f] == 'bad'))
# Out:
# Total videos: 200
# Good vs. Bad counts: 100 100

# %%
# Split video_paths into train/test, stratified by file_labels
train_paths, test_paths = train_test_split(
    video_paths,
    test_size=0.2,
    random_state=42,
    stratify=[file_labels[os.path.basename(p)] for p in video_paths]
)

print(f"Train: {len(train_paths)} videos, Test: {len(test_paths)} videos")
# Out:
# Train: 160 videos, Test: 40 videos

# %%
print(train_paths)
# Out:
# ['/content/bad_form_250/00025920.mp4', '/content/good_form_250/00056098.mp4', '/content/bad_form_250/00042206.mp4', '/content/good_form_250/00001629.mp4', '/content/good_form_250/00047321.mp4', '/content/good_form_250/00063252.mp4', '/content/bad_form_250/00011260.mp4', '/content/bad_form_250/00022393.mp4', '/content/bad_form_250/00037963.mp4', '/content/bad_form_250/00026882.mp4', '/content/bad_form_250/00039996.mp4', '/content/bad_form_250/00016923.mp4', '/content/good_form_250/00006250.mp4', '/content/good_form_250/00031002.mp4', '/content/good_form_250/00049530.mp4', '/content/bad_form_250/00004827.mp4', '/content/bad_form_250/00010209.mp4', '/content/bad_form_250/00052683.mp4', '/content/bad_form_250/00004947.mp4', '/content/good_form_250/00027455.mp4', '/content/bad_form_250/00050458.mp4', '/content/bad_form_250/00033067.mp4', '/content/good_form_250/00066658.mp4', '/content/good_form_250/00047791.mp4', '/content/good_form_250/00066006.mp4', '/content/bad_form_250/00011125.mp4', '/content/bad_form_250/00042887.mp4', '/content/bad_form_250/00001051.mp4', '/content/good_form_250/00045303.mp4', '/content/good_form_250/00050185.mp4', '/content/good_form_250/00023207.mp4', '/content/good_form_250/00018122.mp4', '/content/good_form_250/00053138.mp4', '/content/bad_form_250/00015929.mp4', '/content/good_form_250/00057406.mp4', '/content/bad_form_250/00053925.mp4', '/content/bad_form_250/00003707.mp4', '/content/good_form_250/00028370.mp4', '/content/bad_form_250/00007723.mp4', '/content/bad_form_250/00012406.mp4', '/content/good_form_250/00044671.mp4', '/content/good_form_250/00045876.mp4', '/content/good_form_250/00024720.mp4', '/content/good_form_250/00017483.mp4', '/content/bad_form_250/00020075.mp4', '/content/bad_form_250/00005486.mp4', '/content/good_form_250/00070178.mp4', '/content/good_form_250/00041545.mp4', '/content/bad_form_250/00052784.mp4', '/content/good_form_250/00048122.mp4', '/content/bad_form_250/00031558.mp4', '/content/good_form_250/00038915.mp4', '/content/bad_form_250/00023206.mp4', '/content/good_form_250/00065575.mp4', '/content/bad_form_250/00029323.mp4', '/content/bad_form_250/00022513.mp4', '/content/good_form_250/00015808.mp4', '/content/bad_form_250/00043787.mp4', '/content/bad_form_250/00053009.mp4', '/content/bad_form_250/00023760.mp4', '/content/good_form_250/00037415.mp4', '/content/good_form_250/00058476.mp4', '/content/bad_form_250/00016943.mp4', '/content/bad_form_250/00025012.mp4', '/content/bad_form_250/00020200.mp4', '/content/bad_form_250/00017429.mp4', '/content/good_form_250/00057616.mp4', '/content/bad_form_250/00014696.mp4', '/content/good_form_250/00048903.mp4', '/content/bad_form_250/00037947.mp4', '/content/bad_form_250/00048047.mp4', '/content/bad_form_250/00018989.mp4', '/content/good_form_250/00027515.mp4', '/content/good_form_250/00049976.mp4', '/content/bad_form_250/00040979.mp4', '/content/bad_form_250/00023278.mp4', '/content/good_form_250/00066435.mp4', '/content/bad_form_250/00043168.mp4', '/content/good_form_250/00015464.mp4', '/content/good_form_250/00055847.mp4', '/content/bad_form_250/00026308.mp4', '/content/bad_form_250/00018173.mp4', '/content/good_form_250/00020478.mp4', '/content/good_form_250/00067044.mp4', '/content/good_form_250/00062557.mp4', '/content/bad_form_250/00024907.mp4', '/content/bad_form_250/00026364.mp4', '/content/good_form_250/00062047.mp4', '/content/bad_form_250/00051952.mp4', '/content/good_form_250/00025171.mp4', '/content/bad_form_250/00036064.mp4', '/content/good_form_250/00053082.mp4', '/content/bad_form_250/00041404.mp4', '/content/good_form_250/00053265.mp4', '/content/bad_form_250/00037535.mp4', '/content/good_form_250/00045516.mp4', '/content/good_form_250/00045059.mp4', '/content/good_form_250/00015461.mp4', '/content/bad_form_250/00002820.mp4', '/content/bad_form_250/00021131.mp4', '/content/bad_form_250/00053835.mp4', '/content/good_form_250/00038721.mp4', '/content/bad_form_250/00047117.mp4', '/content/bad_form_250/00019645.mp4', ...

# %%
def trim_to_min(frames, min_seq_len):
  return frames[:min_seq_len]

# Load just the training videos into two parallel lists
train_videos, train_seq_lens = [], []
max_len = 0
min_len = float('inf')
# min_len = sys.maxint
for p in train_paths:
  frames = read_video(p)
  train_videos.append(frames)
  train_seq_lens.append(len(frames))
  max_len = max(max_len, len(frames))
  min_len = min(min_len, len(frames))

# # Trim all videos to the minimum length
# train_videos = np.array([trim_to_min(v, min_len) for v in train_videos])

# Padding function call, since this is basically our version of the load_videos, minus the drive stuff
train_videos = np.array([pad_zeros(v, max_len) for v in train_videos])

# %%
# Not sure if this is actually needed, but probably better to do it than not.
test_videos, test_seq_lens = [], []
max_len_test = 0
min_len_test = float('inf')
for p in test_paths:
  frames = read_video(p)
  test_videos.append(frames)
  test_seq_lens.append(len(frames))
  max_len_test = max(max_len_test, len(frames))
  min_len_test = min(min_len, len(frames))

test_videos = np.array([pad_zeros(v, max_len) for v in test_videos])

# %% [markdown]
# ## Set Hyperparams

# %%
##@title
BATCH_SIZE =  3#@param {type:"integer"}
NUM_STEPS = 32 #@param {type:"integer"}
NUM_CONTEXT_STEPS =  2#@param {type:"integer"}
CONTEXT_STRIDE =  15#@param {type:"integer"}

LOSS_TYPE = 'regression_mse_var' #@param ["regression_mse_var", "regression_mse", "regression_huber", "classification"]
STOCHASTIC_MATCHING = False #@param ["False", "True"] {type:"raw"}
SIMILARITY_TYPE = 'l2' #@param ["l2", "cosine"]
EMBEDDING_SIZE =  128 #@param {type:"integer"}
TEMPERATURE = 0.1 #@param {type:"number"}
LABEL_SMOOTHING = 0.6 #@param {type:"slider", min:0, max:1, step:0.05}
VARIANCE_LAMBDA = 0.001 #@param {type:"number"}
HUBER_DELTA = 0.1 #@param {type:"number"}
NORMALIZE_INDICES = True #@param ["False", "True"] {type:"raw"}
NORMALIZE_EMBEDDINGS = False #@param ["False", "True"] {type:"raw"}

CYCLE_LENGTH = 2 #@param {type:"integer"}
NUM_CYCLES = 32 #@param {type:"integer"}

LEARNING_RATE = 7e-5 #@param {type:"number"}
DEBUG = False #@param ["False", "True"] {type:"raw"}

# %% [markdown]
# ## Create Model and Training Loop based on Hyperparams
# After setting the hyperparams above, initialize dataloader, model, optimizer and training loop.

# %%
LOGDIR = '/content/tcc/'

# Uncomment this to clear up logdir. Be careful this is removing files from
# your Google Drive.
# %rm -r "$LOGDIR"
# If LOGDIR is on Drive, when the training loop deletes old checkpoints they
# end up in the trash of Google Drive. You may need to clear up that space.

train_ds = create_dataset(train_videos, train_seq_lens,
                        batch_size=BATCH_SIZE,
                        num_steps=NUM_STEPS,
                        num_context_steps=NUM_CONTEXT_STEPS,
                        context_stride=CONTEXT_STRIDE)
model = Embedder(EMBEDDING_SIZE, NORMALIZE_EMBEDDINGS, NUM_CONTEXT_STEPS)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
ckpt = tf.train.Checkpoint(optimizer=optimizer, model=model)
manager = tf.train.CheckpointManager(ckpt, LOGDIR, max_to_keep=3)
summary_writer = tf.summary.create_file_writer(LOGDIR, flush_millis=1000)

@tf.function
def train_one_iter(data):
  frames = data['frames']
  steps = data['steps']
  seq_lens = data['seq_lens']
  with tf.GradientTape() as tape:
    embs = model(frames, training=True)
    trainable_variables = model.trainable_variables
    if STOCHASTIC_MATCHING:
      loss = compute_stochastic_alignment_loss(embs,
                                        steps,
                                        seq_lens,
                                        num_cycles=NUM_CYCLES,
                                        cycle_length=CYCLE_LENGTH,
                                        num_steps=NUM_STEPS,
                                        batch_size=BATCH_SIZE,
                                        loss_type=LOSS_TYPE,
                                        similarity_type=SIMILARITY_TYPE,
                                        temperature=TEMPERATURE,
                                        label_smoothing=LABEL_SMOOTHING,
                                        variance_lambda=VARIANCE_LAMBDA,
                                        huber_delta=HUBER_DELTA,
                                        normalize_indices=NORMALIZE_INDICES)
    else:
        loss = compute_deterministic_alignment_loss(embs,
                                        steps,
                                        seq_lens,
                                        num_steps=NUM_STEPS,
                                        batch_size=BATCH_SIZE,
                                        loss_type=LOSS_TYPE,
                                        similarity_type=SIMILARITY_TYPE,
                                        temperature=TEMPERATURE,
                                        label_smoothing=LABEL_SMOOTHING,
                                        variance_lambda=VARIANCE_LAMBDA,
                                        huber_delta=HUBER_DELTA,
                                        normalize_indices=NORMALIZE_INDICES)
    # Add regularization losses.
    if model.losses:
      loss += tf.add_n(model.losses)

  grads = tape.gradient(loss, trainable_variables)
  optimizer.apply_gradients(zip(grads, trainable_variables))

  with tf.summary.record_if(tf.math.equal(
      tf.math.mod(optimizer.iterations, 10), 0)):
    tf.summary.scalar('loss', loss, optimizer.iterations)
    if DEBUG:
      for var_ in model.variables:
        tf.summary.histogram(var_.name, var_, step=optimizer.iterations)
      _, n, h, w, c = frames.shape
      tf.summary.image('frames', tf.cast(
        255.0*(tf.squeeze(tf.concat(tf.split(frames, n, axis=1),
                                    axis=3), axis=1)+1.0)/2.0, tf.uint8),
                      optimizer.iterations)

  return loss
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %% [markdown]
# ## Train the model

# %%
from tqdm import tqdm

# %tensorboard --logdir "$LOGDIR"

NUM_TRAINING_STEPS = 10000 #10000
SAVE_CKPT_STEPS = 500

# Uncomment this to load previous checkpoint.
ckpt.restore(manager.latest_checkpoint)

i = 0

with summary_writer.as_default():
  with tqdm(total=NUM_TRAINING_STEPS,
            desc="Training Progress",
            position=0,
            leave=True,
            dynamic_ncols=True) as pbar:

      for i, data in enumerate(train_ds.take(NUM_TRAINING_STEPS)):
        loss = train_one_iter(data)

        if i % SAVE_CKPT_STEPS == 0:
          manager.save()

        # Sometimes tensorboard doesn't load, so this is just so we can view the loss and iteration no matter what.
        pbar.set_postfix({'loss': f'{loss.numpy():.4f}'})
        pbar.update(1)

# %%
# Save model if you inerrupted training or finished training.
# If you had to stop training while it was happening, you may have to restart the runtime to clear the GPU memory.
manager.save()

# %% [markdown]
# # Applications using encoder trained with TCC

# %% [markdown]
# ## Extract Per-frame Embeddings
# Use the trained encoder to extract per-frame embeddings.

# %%
PATH_TO_EMBS = os.path.join(LOGDIR, 'embeddings.npy')

# %%
FRAMES_PER_BATCH = 80 # Change if you have more GPU memory.
train_embs = get_embs(
    model, train_videos, train_seq_lens,
    frames_per_batch=FRAMES_PER_BATCH,
    num_context_steps=NUM_CONTEXT_STEPS,
    context_stride=CONTEXT_STRIDE
)

test_embs = get_embs(
    model, test_videos, test_seq_lens,
    frames_per_batch=FRAMES_PER_BATCH,
    num_context_steps=NUM_CONTEXT_STEPS,
    context_stride=CONTEXT_STRIDE
)

embs_all = train_embs + test_embs

# # Save the embeddings so that you don't have to use GPU for later experiments.

embs_arr = np.array(embs_all, dtype=object)         # <— dtype=object allows ragged sequences :contentReference[oaicite:4]{index=4}
np.save(PATH_TO_EMBS, embs_arr, allow_pickle=True)

# %%
# Load previously saved embeddings in case you have them stored.
embs_arr = np.load(PATH_TO_EMBS, allow_pickle=True)
embs_all = embs_arr.tolist()

# %% [markdown]
# ## Few-shot learning to propagate phase/segment labels
#
# Since the model finds similarities across videos, we can manually label the segments for a handful of videos (as few as one) and let TCC automatically propagate these labels across different videos. Potentially these labels can be used to create datasets for other downstream tasks.
#
# ![alt text](https://temporal-cycle-consistency.github.io/assets/fig/annotation.png)
#
# We provide a simple utility to label videos manually. If you play the video using the `play_video` function, it shows the frame number. You can use that to provide label segments for some videos in the following format.
#
# `labels = {
#   video_id_0: [Frame # when segment 0 ends,
#               Frame # when segment 1 ends, ... ],
#   video_id_1: [Frame # when segment 0 ends,
#               Frame # when segment 1 ends, ... ],
#               }`
#
# where `video_id_x` corresponds to the index in the videos array.
#
# Maintain a labels dictionary in the following format and add labels as you play multiple videos.

# %%
VIDEO_ID = 71
play_video(train_videos[VIDEO_ID], train_seq_lens[VIDEO_ID])
# Out:
# <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %% [markdown]
# Add labels to a label dict as the video plays above:

# %%
labels = {89: [173, 173, 173],
          30: [0, 0, 176],
          136: [177, 177, 177],
          9: [0, 11, 173],
          102: [147, 147, 147],
          71: [28, 153, 153]}

# %% [markdown]
# Optionally, create human readable labels for the class labels. For example:
#
# `label_strings = ['Hand Reaching', 'Lifting Bottle', 'Pouring Liquid', 'Placing Bottle', 'Hand Receding']`

# %%
label_strings = ['Ideal Alignment', 'Compensatory Alignment', 'Positional Deviation']
#                   0                      1                       2
# To better synchronize, we've added a 4th label to account if the user starts on a different phase of the exercise.

# %% [markdown]
# Propagate labels from the few manually labeled videos to the entire dataset. `propagated_labels` is a list of per-frame labels for each video.

# %%
propagated_all = propagate_labels(embs_all, labels)

# len(train_embs) = len(train_paths)
print(len(train_paths))
prop_train = propagated_all[:len(train_paths)]
prop_test  = propagated_all[len(train_paths):]
# Out:
# [LibSVM]Label propagation model accuracy: 0.9569569569569569
# If this is too low, propagation will not work properly.
# 160

# %% [markdown]
# Visualize the propagated labels to get a sense of how well the label propagation worked.

# %%
VIDEO_ID = np.random.choice(len(train_videos))
print('Visualizing video %d'%VIDEO_ID)
viz_propagated_labels(train_videos[VIDEO_ID],
                      prop_train[VIDEO_ID],
                      train_seq_lens[VIDEO_ID],
                      label_strings)
# Out:
# Visualizing video 65
# <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %% [markdown]
# # Binary classification

# %%
def majority_vote_classifier(frame_labels, discard_label=None):
    """
    Count how many frames are assigned to each ROM label,
    ignore any 'discard_label' frames,
    then apply majority-vote: label==1 ⇒ good (1), else bad (0).
    """
    labels = frame_labels
    if discard_label is not None:
        labels = labels[labels != discard_label]
    if labels.size == 0:
        # No valid frames ⇒ default to bad
        return 0
    uniq, counts = np.unique(labels, return_counts=True)
    maj_label = uniq[np.argmax(counts)]
    return 1 if maj_label in [0, 1] else 0

# Apply to each video in train/test
y_train_pred = np.array([
    majority_vote_classifier(pl, discard_label=0)
    for pl in prop_train
])
y_test_pred = np.array([
    majority_vote_classifier(pl, discard_label=0)
    for pl in prop_test
])

# Re-load your ground-truth binary labels
y_train = np.array([
    1 if file_labels[os.path.basename(p)] == 'good' else 0
    for p in train_paths
])
y_test = np.array([
    1 if file_labels[os.path.basename(p)] == 'good' else 0
    for p in test_paths
])

tn_tr, fp_tr, fn_tr, tp_tr = confusion_matrix(y_train, y_train_pred).ravel()
tn_te, fp_te, fn_te, tp_te = confusion_matrix(y_test,  y_test_pred).ravel()

f1_tr = f1_score(y_train, y_train_pred)
f1_te = f1_score(y_test,  y_test_pred)

print("=== MAJORITY-VOTE CLASSIFIER BASED ON FRAME COUNTS ===\n")

print("=== TRAIN SET ===")
print(f"True Positives:  {tp_tr}")
print(f"True Negatives:  {tn_tr}")
print(f"False Positives: {fp_tr}")
print(f"False Negatives: {fn_tr}")
print(f"F1-Score:        {f1_tr:.3f}\n")

print("=== TEST SET ===")
print(f"True Positives:  {tp_te}")
print(f"True Negatives:  {tn_te}")
print(f"False Positives: {fp_te}")
print(f"False Negatives: {fn_te}")
print(f"F1-Score:        {f1_te:.3f}")
# Out:
# === MAJORITY-VOTE CLASSIFIER BASED ON FRAME COUNTS ===
#
# === TRAIN SET ===
# True Positives:  7
# True Negatives:  70
# False Positives: 10
# False Negatives: 73
# F1-Score:        0.144
#
# === TEST SET ===
# True Positives:  2
# True Negatives:  17
# False Positives: 3
# False Negatives: 18
# F1-Score:        0.160

# %% [markdown]
# Accuracy: 47.5%
#
# Precision: 40.0%
#
# Recall: 10.0%
#
# F1-Score: 16.0%

# %% [markdown]
# # Citation
#
# If you found our paper/code useful in your research, consider citing our paper:
#
#
# ```
# author = {Dwibedi, Debidatta and Aytar, Yusuf and Tompson, Jonathan and Sermanet, Pierre and Zisserman, Andrew},
# title = {Temporal Cycle-Consistency Learning},
# booktitle = {The IEEE Conference on Computer Vision and Pattern Recognition (CVPR)},
# month = {June},
# year = {2019},
# }
# ```
